# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import mnist
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# %% [markdown]
# ## Normalizing and Reshaping:

# %%
X_train = X_train / 255.0
X_test = X_test / 255.0
X_train = X_train.reshape(-1, 28, 28, 1)
X_test = X_test.reshape(-1, 28, 28, 1)

# %% [markdown]
# ## Epochs:

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
model = Sequential([Flatten(input_shape=(28, 28, 1)), Dense(128, activation='relu'), Dense(10, activation='softmax')])
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=10, validation_split=0.2)
# Out:
# Epoch 1/10
# C:\Users\uchih\anaconda3\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8611 - loss: 0.4902 - val_accuracy: 0.9543 - val_loss: 0.1626
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9601 - loss: 0.1355 - val_accuracy: 0.9675 - val_loss: 0.1136
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9750 - loss: 0.0870 - val_accuracy: 0.9662 - val_loss: 0.1087
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9824 - loss: 0.0620 - val_accuracy: 0.9713 - val_loss: 0.0921
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9861 - loss: 0.0481 - val_accuracy: 0.9741 - val_loss: 0.0911
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9894 - loss: 0.0357 - val_accuracy: 0.9727 - val_loss: 0.0907
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9921 - loss: 0.0284 - val_accuracy: 0.9750 - val_loss: 0.0896
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9939 - loss: 0.0214 - val_accuracy: 0.9758 - val_loss: 0.0895
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9945 - loss: 0.0184 - val_accuracy: 0.9729 - val_loss: 0.0963
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9960 - loss: 0.0147 - val_accuracy: 0.9728 - val_loss: 0.1078

# %% [markdown]
# ## Model Training

# %%
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

# Flattening images to 1D from 2D
X_train_flat = X_train.reshape(-1, 28 * 28)
X_test_flat = X_test.reshape(-1, 28 * 28)

# Support Vector Machine
svm_model = SVC()
svm_model.fit(X_train_flat, y_train)

# K-Nearest Neighbour
knn_model = KNeighborsClassifier()
knn_model.fit(X_train_flat, y_train)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# ## Report:

# %%
from sklearn.metrics import classification_report, accuracy_score

# Evaluate models
y_pred_nn = model.predict(X_test).argmax(axis=1)
print("NN Classification Report:")
print(classification_report(y_test, y_pred_nn))

y_pred_svm = svm_model.predict(X_test_flat)
print("SVM Accuracy:", accuracy_score(y_test, y_pred_svm))

y_pred_knn = knn_model.predict(X_test_flat)
print("KNN Accuracy:", accuracy_score(y_test, y_pred_knn))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# NN Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99       980
#            1       0.99      1.00      0.99      1135
#            2       0.95      0.99      0.97      1032
#            3       0.97      0.97      0.97      1010
#            4       0.97      0.98      0.98       982
#            5       0.98      0.97      0.97       892
#            6       0.99      0.96      0.98       958
#            7       0.97      0.98      0.97      1028
#            8       0.97      0.96      0.97       974
#            9       0.98      0.96      0.97      1009
#
#     accuracy                           0.97     10000
#    macro avg       0.98      0.97      0.97     10000
# weighted avg       0.98      0.97      0.97     10000
#
# SVM Accuracy: 0.9792
# KNN Accuracy: 0.9688
